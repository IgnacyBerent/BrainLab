# %%
import prep
import prsa
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = 'data_2/normokapnia'
files_n = []
for filename in os.listdir(data_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_path, filename)
        try:
            df = prep.read_data(file_path, 'abp_finger_mm_hg_[abp_finger_mm_Hg_]', sep=';')
        except KeyError:
            df = prep.read_data(file_path, 'abp_finger[abp_finger]', sep=';')
        files_n.append(df)
        prep.describe_file(df, filename)
        print('')

prep.files_time_analysis(files_n)
# Out:
# File name: e[1]_[n]_[45].csv
# File size: 63425
# Total measurement time: 5:17 min
# Percent of missing data: 0.12%
#
# File name: e[3]_[n]_[01].csv
# File size: 53819
# Total measurement time: 4:29 min
# Percent of missing data: 0.72%
#
# File name: e[3]_[n]_[03].csv
# File size: 54745
# Total measurement time: 4:33 min
# Percent of missing data: 0.70%
#
# File name: e[3]_[n]_[04].csv
# File size: 69001
# Total measurement time: 5:45 min
# Percent of missing data: 0.56%
#
# File name: e[3]_[n]_[05].csv
# File size: 78001
# Total measurement time: 6:30 min
# Percent of missing data: 0.49%
#
# File name: e[3]_[n]_[07].csv
# File size: 64401
# Total measurement time: 5:22 min
# Percent of missing data: 3.61%
#
# File name: e[3]_[n]_[08].csv
# File size: 63401
# Total measurement time: 5:17 min
# Percent of missing data: 2.55%
#
# File name: e[3]_[n]_[09].csv
# File size: 58549
# Total measurement time: 4:52 min
# Percent of missing data: 0.13%
#
# File name: e[3]_[n]_[10].csv
# ...

# %%
data_path = 'data_2/hiperkapnia'
files_h = []
for filename in os.listdir(data_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_path, filename)
        try:
            df = prep.read_data(file_path, 'abp_finger_mm_hg_[abp_finger_mm_Hg_]', sep=';')
        except KeyError:
            df = prep.read_data(file_path, 'abp_finger[abp_finger]', sep=';')
        files_h.append(df)
        prep.describe_file(df, filename)
        print('')
        
prep.files_time_analysis(files_h)
# Out:
# File name: e[1]_[n]_[45].csv
# File size: 63425
# Total measurement time: 5:17 min
# Percent of missing data: 0.12%
#
# File name: e[3]_[n]_[01].csv
# File size: 53819
# Total measurement time: 4:29 min
# Percent of missing data: 0.72%
#
# File name: e[3]_[n]_[03].csv
# File size: 54745
# Total measurement time: 4:33 min
# Percent of missing data: 0.70%
#
# File name: e[3]_[n]_[04].csv
# File size: 69001
# Total measurement time: 5:45 min
# Percent of missing data: 0.56%
#
# File name: e[3]_[n]_[05].csv
# File size: 78001
# Total measurement time: 6:30 min
# Percent of missing data: 0.49%
#
# File name: e[3]_[n]_[07].csv
# File size: 64401
# Total measurement time: 5:22 min
# Percent of missing data: 3.61%
#
# File name: e[3]_[n]_[08].csv
# File size: 63401
# Total measurement time: 5:17 min
# Percent of missing data: 2.55%
#
# File name: e[3]_[n]_[09].csv
# File size: 58549
# Total measurement time: 4:52 min
# Percent of missing data: 0.13%
#
# File name: e[3]_[n]_[10].csv
# ...
